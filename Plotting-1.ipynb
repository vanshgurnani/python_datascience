# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv('df1',index_col=0)
data2=pd.read_csv('df2',index_col=0)
data3=pd.read_csv('df3')

# %%
data1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
data2.head()
# Out:
#                  b         c         d
# a
# 0.039762  0.218517  0.103423  0.957904
# 0.937288  0.041567  0.899125  0.977680
# 0.780504  0.008948  0.557808  0.797510
# 0.672717  0.247870  0.264071  0.444358
# 0.053829  0.520124  0.552264  0.190008

# %%
data3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
sns.set_style('darkgrid')
data1['A'].hist(bins=30)

# %%
data2.plot.area(alpha=0.5)

# %%
data2.plot.bar()

# %%
data1.plot.line(y='B',figsize=(12,3))

# %%
data1.index
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20', '2002-09-21',
#        '2002-09-22', '2002-09-23', '2002-09-24', '2002-09-25', '2002-09-26'],
#       dtype='object', length=1000)

# %%
data1.plot.scatter(x='A',y='B',s=data1['C']*50)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py:885: RuntimeWarning:
#
# invalid value encountered in sqrt

# %%
data2.plot.box()

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['A','B'])
df.head()
# Out:
#           A         B
# 0 -2.074075  0.255635
# 1 -1.398512 -1.134030
# 2  0.058118 -0.135559
# 3  0.718819  1.950216
# 4  1.316995  0.049950

# %%
df['A'].plot.density()

# %%
data3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
data3.plot.scatter(x='a',y='b',figsize=(12,3))

# %%
plt.style.use('ggplot')

# %%
data3['a'].plot.hist(bins=30,alpha=0.5)

# %%
data3[['a','b']].plot.box()

# %%
data3['d'].plot.kde()

# %%
data3['d'].plot.density(ls='--',lw=3)

# %%
data3.iloc[0:30].plot.area(alpha=0.5)

# %%
f = plt.figure()
data3.iloc[0:30].plot.area(alpha=0.4,ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
# %matplotlib inline
from plotly import __version__

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1=pd.DataFrame(np.random.randn(1000,4),columns=['A','B','C','D'])
df1.head()
# Out:
#           A         B         C         D
# 0 -1.019672 -1.553404  0.171229 -0.726282
# 1  0.289030  0.672914  0.838861 -0.200814
# 2 -0.749207 -2.315830  0.699466  0.308956
# 3  0.390233  0.203749 -0.158470  0.153772
# 4  0.451547  0.315007  0.007246  0.553062

# %%
df2=pd.DataFrame({'Category':['A','B','C'],
                  'Values':[32,43,50]})
df2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
# Out:
# <div>                            <div id="74f807be-98b0-433d-a15a-4c97956d96ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
