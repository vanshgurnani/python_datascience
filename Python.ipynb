# %%
# QUESTION 2
MY=(1,2,[3,2,1],4,5)
MY[2].sort()
MY[2]
# Out:
# [1, 2, 3]

# %%
# QUESTION 3
t1=((1,'a'),(2,'b'),(3,'c'))
dic=dict(t1)
dic
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
# QUESTION 1
t1=((1,2,3),1,(1,2,3))
t3=tuple(set(t1))
t3
# Out:
# (1, (1, 2, 3))

# %%
# QUESTION 4
t1=(1,2,3)
t2=(1,1,1)
add=[]

for i in range(0,len(t1)):
  add.append(t1[i]+t2[i])
add=tuple(add)
add
# Out:
# (2, 3, 4)

# %%
# QUESTION 5
t1=([1,2,3],[2,2,2])
m=[]

# t3=t1[0][1]*t1[1][0]
# t3

for i in range(0,len(t1)):
  for j in range(0,len(t1[i])):
    m.append(t1[i][j]*t1[i-1][j])
m=tuple(set(m))
m
# Out:
# (2, 4, 6)
